# %%
# importing the libraries
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
import pathlib
import os

# %%
# current working directory
working_directory = pathlib.Path(os.getcwd())
working_parent_directory = working_directory.parent

# dataset path 
flat_dataset_location = os.path.join(working_parent_directory, 'dataset/flats.csv')

# %%
# loading the dataset into pandas dataframe
df = pd.read_csv(flat_dataset_location)

# shape of the dataset
print(f"Shape of the dataset: {df.shape}")
# Out:
# Shape of the dataset: (3017, 21)

# %%
# removing the view restriction from pandas dataframe
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
# viewing first 5 samples from the dataset
df.head(5)
# Out:
#    Unnamed: 0                    property_name  \
# 0           0     2 BHK Flat in Krishna Colony
# 1           1        2 BHK Flat in Ashok Vihar
# 2           2              2 BHK Flat in Sohna
# 3           3  2 BHK Flat in Sector 61 Gurgaon
# 4           4  2 BHK Flat in Sector 92 Gurgaon
#
#                                                 link                 society  \
# 0  https://www.99acres.com/2-bhk-bedroom-apartmen...  maa bhagwati residency
# 1  https://www.99acres.com/2-bhk-bedroom-apartmen...            Apna Enclave
# 2  https://www.99acres.com/2-bhk-bedroom-apartmen...  Tulsiani Easy in Homes
# 3  https://www.99acres.com/2-bhk-bedroom-apartmen...     Smart World Orchard
# 4  https://www.99acres.com/2-bhk-bedroom-apartmen...        Parkwood Westend
#
#         price             area                            areaWithType  \
# 0      45 Lac   ₹ 5,000/sq.ft.          Carpet area: 900 (83.61 sq.m.)
# 1      50 Lac   ₹ 7,692/sq.ft.          Carpet area: 650 (60.39 sq.m.)
# 2      40 Lac   ₹ 6,722/sq.ft.          Carpet area: 595 (55.28 sq.m.)
# 3  1.47 Crore  ₹ 12,250/sq.ft.        Carpet area: 1200 (111.48 sq.m.)
# 4      70 Lac   ₹ 5,204/sq.ft.  Super Built up area 1345(124.95 sq.m.)
#
#       bedRoom     bathroom      balcony additionalRoom  \
# 0  2 Bedrooms  2 Bathrooms    1 Balcony            NaN
# 1  2 Bedrooms  2 Bathrooms    1 Balcony            NaN
# 2  2 Bedrooms  2 Bathrooms  3 Balconies            NaN
# 3  2 Bedrooms  2 Bathrooms  2 Balconies     Study Room
# 4  2 Bedrooms  2 Bathrooms  3 Balconies     Study Room
#
#                                address             floorNum facing  \
# 0     Krishna Colony, Gurgaon, Haryana    4th   of 4 Floors   West
# 1   46b, Ashok Vihar, Gurgaon, Haryana    1st   of 3 Floors   West
# 2              Sohna, Gurgaon, Haryana  12nd   of 14 Floors    NaN
# 3  Sector 61 Gurgaon, Gurgaon, Haryana    2nd   of 4 Floors    NaN
# 4  Sector 92 Gurgaon, Gurgaon, Haryana    5th   of 8 Floors    NaN
#
#         agePossession                                    nearbyLocations  \
# 0     1 to 5 Year Old  ['Chintapurni Mandir', 'State bank ATM', 'Pear...
# 1        10+ Year Old  ['Chintapurni Mandir', 'Sheetla Mata Mandir', ...
# 2     0 to 1 Year Old  ['Huda City Metro', 'Golf Course extn road', '...
# 3            Dec 2023  ['Sector 55-56 Metro station', 'Bestech Centra...
# 4  Under Construction  ['Yadav Clinic', 'Bangali Clinic', 'Dr. J. S. ...
#
#                                          description  \
# 0  So with lift.Maa bhagwati residency is one of ...
# 1  Property situated on main road, railway statio...
# 2  This property is 15 km away from badshapur, gu...
# 3  Near to metro station of sector 56 and opposit...
# 4  We are the proud owners of this 2 bhk alongwit...
#
#                                       furnishDetails  \
# 0  ['3 Fan', '4 Light', '1 Wardrobe', 'No AC', 'N...
# 1  ['3 Wardrobe', '4 Fan', '1 Exhaust Fan', '1 Ge...
# 2                                                NaN
# 3                                                NaN
# 4                                                 []
#
#                                             features  \
# 0  ['Feng Shui / Vaastu Compliant', 'Security / F...
# 1  ['Security / Fire Alarm', 'Maintenance Staff',...
# 2  ['Power Back-up', 'Feng Shui / Vaastu Complian...
# 3  ['Security / Fire Alarm', 'Private Garden / Te...
# 4                                                NaN
#
#                                               rating property_id
# 0  ['Environment4 out of 5', 'Safety4 out of 5', ...   C68850746
# 1  ['Environment4 out of 5', 'Safety4 out of 5', ...   H68850564
# 2  ['Environment4 out of 5', 'Safety4 out of 5', ...   J68850120
# 3                                                NaN   S68849476
# 4  ['Environment5 out of 5', 'Safety3 out of 5', ...   L47956793

# %%
# checking datatypes in the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3017 entries, 0 to 3016
# Data columns (total 21 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       3017 non-null   int64
#  1   property_name    3017 non-null   object
#  2   link             3017 non-null   object
#  3   society          3016 non-null   object
#  4   price            3007 non-null   object
#  5   area             3004 non-null   object
#  6   areaWithType     3008 non-null   object
#  7   bedRoom          3008 non-null   object
#  8   bathroom         3008 non-null   object
#  9   balcony          3008 non-null   object
#  10  additionalRoom   1694 non-null   object
#  11  address          3002 non-null   object
#  12  floorNum         3006 non-null   object
#  13  facing           2127 non-null   object
#  14  agePossession    3007 non-null   object
#  15  nearbyLocations  2913 non-null   object
#  16  description      3008 non-null   object
#  17  furnishDetails   2203 non-null   object
#  18  features         2594 non-null   object
#  19  rating           2676 non-null   object
#  20  property_id      3008 non-null   object
# dtypes: int64(1), object(20)
# memory usage: 495.1+ KB

# %%
# checking for duplicate rows
df.duplicated().sum()
# Out:
# 0

# %%
# missing values in the dataset
df.isnull().sum().sort_values(ascending=False)
# Out:
# additionalRoom     1323
# facing              890
# furnishDetails      814
# features            423
# rating              341
# nearbyLocations     104
# address              15
# area                 13
# floorNum             11
# price                10
# agePossession        10
# description           9
# property_id           9
# balcony               9
# bathroom              9
# bedRoom               9
# areaWithType          9
# society               1
# property_name         0
# link                  0
# Unnamed: 0            0
# dtype: int64

# %%
# dropping the columns which will not help in data analysis and machine learning
df.drop(columns=['link', 'property_id', 'Unnamed: 0'], inplace=True)

# %%
# checking few samples after dropping the columns
df.sample(5)
# Out:
#                          property_name                   society       price  \
# 2589  2 BHK Flat in Sector 10A Gurgaon  Maxworth City Residences      90 Lac
# 790   2 BHK Flat in Sector 99A Gurgaon             Prime Habitat    27.1 Lac
# 828    3 BHK Flat in Sector 69 Gurgaon         Tulip Violet4.2 ★  1.43 Crore
# 1388   2 BHK Flat in Sector 83 Gurgaon    Vatika Gurgaon 213.7 ★      83 Lac
# 693   3 BHK Flat in Sector 109 Gurgaon                ATS Kocoon  1.75 Crore
#
#                  area                                       areaWithType  \
# 2589   ₹ 7,083/sq.ft.             Super Built up area 1200(111.48 sq.m.)
# 790    ₹ 6,049/sq.ft.                     Carpet area: 448 (41.62 sq.m.)
# 828    ₹ 8,886/sq.ft.             Super Built up area 1608(149.39 sq.m.)
# 1388   ₹ 6,666/sq.ft.  Super Built up area 1245(115.66 sq.m.)Built Up...
# 693   ₹ 10,028/sq.ft.  Super Built up area 1745(162.12 sq.m.)Built Up...
#
#          bedRoom     bathroom      balcony additionalRoom  \
# 2589  2 Bedrooms  2 Bathrooms  3 Balconies         Others
# 790   2 Bedrooms  2 Bathrooms    1 Balcony            NaN
# 828   3 Bedrooms  3 Bathrooms  2 Balconies     Pooja Room
# 1388  2 Bedrooms  2 Bathrooms  2 Balconies     Pooja Room
# 693   3 Bedrooms  3 Bathrooms  3 Balconies     Pooja Room
#
#                                                 address             floorNum  \
# 2589  Maxworth City Residences, Sector 10A Gurgaon, ...   9th   of 11 Floors
# 790                Sector 99A Gurgaon, Gurgaon, Haryana  10th   of 12 Floors
# 828                 Sector 69 Gurgaon, Gurgaon, Haryana   1st   of 14 Floors
# 1388      Tower F1, Sector 83 Gurgaon, Gurgaon, Haryana  12nd   of 18 Floors
# 693        Middle, Sector 109 Gurgaon, Gurgaon, Haryana  10th   of 25 Floors
#
#           facing    agePossession  \
# 2589        East  0 to 1 Year Old
# 790        South  1 to 5 Year Old
# 828   North-West  1 to 5 Year Old
# 1388       North  1 to 5 Year Old
# 693   North-East  1 to 5 Year Old
#
#                                         nearbyLocations  \
# 2589  ['Rajiv Chowk Mosque', 'Yadav Hospital Gurgoan...
# 790   ['The Hive Mall', 'Omaxe Gurgaon Mall', 'Gurug...
# 828   ['Airia Mall Sector 68', 'Southern Peripheral ...
# 1388  ['Huda Metro Station (Gurugram)', 'Sapphire 83...
# 693   ['Jagdish Super Market', 'Dwarka', 'Euro Inter...
#
#                                             description  \
# 2589  2 bhk apartment in very good locality. Just 2....
# 790   This lovely 2 bhk apartment/flat in sector 99a...
# 828   This beautiful 3 bhk flat in sector 69 gurgaon...
# 1388  Vatika gurgaon 21 is one of the most popular d...
# 693   This beautiful 3 bhk flat in sector 109 gurgao...
#
#                                          furnishDetails  \
# 2589                                                 []
# 790                                                 NaN
# 828   ['1 Modular Kitchen', 'No AC', 'No Bed', 'No C...
# 1388                                                NaN
# 693   ['1 Water Purifier', '5 Fan', '1 Exhaust Fan',...
#
#                                                features  \
# 2589  ['Security / Fire Alarm', 'Intercom Facility',...
# 790   ['Security / Fire Alarm', 'Lift(s)', 'Maintena...
# 828   ['Power Back-up', 'Feng Shui / Vaastu Complian...
# 1388  ['Water purifier', 'Security / Fire Alarm', 'P...
# 693   ['Feng Shui / Vaastu Compliant', 'Security / F...
#
#                                                  rating
# 2589  ['Environment4 out of 5', 'Safety5 out of 5', ...
# 790   ['Environment4 out of 5', 'Lifestyle3 out of 5...
# 828   ['Green Area5 out of 5', 'Construction4 out of...
# 1388  ['Green Area5 out of 5', 'Construction4.5 out ...
# 693   ['Green Area5 out of 5', 'Construction5 out of...
